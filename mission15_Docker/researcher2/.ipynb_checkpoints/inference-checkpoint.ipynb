# %% [markdown]
# # Researcher2:
# - 연구자 1이 생성한 `model.pkl` 파일을 로드하여 테스트 데이터에 대한 예측을 수행합니다.

# %%
# !pip install scikit-learn==1.7.2

# %%
import pandas as pd
import pickle
import os

# 모델 로드
with open('model.pkl', 'rb') as f:
    model = pickle.load(f)

# 데이터 로드
test_df = pd.read_csv('data/mission15_test.csv')
test_df.head()
# Out:
# /opt/conda/lib/python3.10/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator LinearRegression from version 1.7.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   """Set the parameters of this estimator.
#    Hours Studied  Previous Scores Extracurricular Activities  Sleep Hours  \
# 0              7               99                        Yes            9
# 1              8               51                        Yes            7
# 2              8               91                         No            4
# 3              5               79                         No            7
# 4              2               72                         No            4
#
#    Sample Question Papers Practiced
# 0                                 1
# 1                                 2
# ...

# %%
# 데이터 전처리 
test_df["Extracurricular Activities"] = test_df["Extracurricular Activities"].map({"No": 0, "Yes": 1})

# 만약 test.csv에 정답(Performance Index) 컬럼이 껴있다면 빼고 문제만 줘야 합니다.
if 'Performance Index' in test_df.columns:
    X_test = test_df.drop('Performance Index', axis=1)
else:
    X_test = test_df

# %%
# 추론
predictions = model.predict(X_test)

# 결과 저장 (result.csv)
result_df = pd.DataFrame({
    'Prediction': predictions
})

# index=False 를 줘야 쓸데없는 순번 열이 안 생깁니다.
result_df.to_csv('result.csv', index=False) 

print(f"결과가 '{output_path}'에 저장되었습니다.")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 2
#       1 # 추론
# ----> 2 predictions = model.predict(X_test)
#       4 # 결과 저장 (result.csv)
#       5 result_df = pd.DataFrame({
#       6     'Prediction': predictions
#       7 })
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_base.py:354, in predict(self, X)
#     352 X = validate_data(self, X, accept_sparse="csr", reset=False)
#     353 scores = safe_sparse_dot(X, self.coef_.T, dense_output=True) + self.intercept_
# --> 354 return (
#     355     xp.reshape(scores, (-1,))
#     356     if (scores.ndim > 1 and scores.shape[1] == 1)
#     357     else scores
#     358 )
#
# File /opt/conda/lib/python3.10/site-packages/sklearn/linear_model/_base.py:337, in _decision_function(self, X)
#     330 def decision_function(self, X):
#     331     """
# ...
